# %%
import requests
import json
import os
import time

# List of popular UK cities
uk_cities = ["london", "manchester", "birmingham", "liverpool", "glasgow", "edinburgh", "leeds", "bristol", "sheffield", "newcastle"]

# Display the list of cities as a dropdown-like menu
print("Please select a city from the list of UK cities below:")
for index, city in enumerate(uk_cities, start=1):
    print(f"{index}. {city.capitalize()}")

# Prompt the user to enter a choice
while True:
    try:
        city_choice = int(input("Enter the number corresponding to your chosen city: "))
        if 1 <= city_choice <= len(uk_cities):
            selected_city = uk_cities[city_choice - 1]
            break
        else:
            print("Invalid choice. Please enter a number from the list.")
    except ValueError:
        print("Please enter a valid number.")

# Confirm the selected city
print(f"You selected: {selected_city.capitalize()}")

# Base URL of the API endpoint
base_url = "https://api.neotaste.com/cities/"

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Path to the output JSON file
output_file = f"{selected_city}.json"

# Check if the file already exists; if so, load the existing data
if os.path.exists(output_file):
    with open(output_file, 'r') as file:
        all_restaurants = json.load(file)
else:
    all_restaurants = []

# Pagination handling
page = 1
while True:
    # Construct the URL for the current page and selected city
    url = f"{base_url}{selected_city}/restaurants/?citySlug={selected_city}&page={page}"

    # Send a GET request to the API with headers
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        json_data = response.json()

        # Check if the 'data' field contains restaurant data
        if 'data' in json_data and json_data['data']:
            all_restaurants.extend(json_data['data'])
            print(f"Successfully fetched data from page {page} for {selected_city.capitalize()}")

            # Write the updated list to the JSON file after fetching each page
            with open(output_file, 'w') as file:
                json.dump(all_restaurants, file, indent=4)

            # Increment page counter
            page += 1

            # Delay to avoid API rate-limiting
            time.sleep(1)
        else:
            print(f"No more data found on page {page}. Ending pagination.")
            break
    else:
        # Log and stop fetching if the request fails
        print(f"Error: Unable to fetch data from page {page} for {selected_city.capitalize()} (Status code: {response.status_code})")
        break

# Print the total number of restaurants fetched
print(f"Total restaurants fetched for {selected_city.capitalize()}: {len(all_restaurants)}")
# Out:
# Please select a city from the list of UK cities below:
# 1. London
# 2. Manchester
# 3. Birmingham
# 4. Liverpool
# 5. Glasgow
# 6. Edinburgh
# 7. Leeds
# 8. Bristol
# 9. Sheffield
# 10. Newcastle
# Enter the number corresponding to your chosen city: 3
# You selected: Birmingham
# Successfully fetched data from page 1 for Birmingham
# Successfully fetched data from page 2 for Birmingham
# Successfully fetched data from page 3 for Birmingham
# Successfully fetched data from page 4 for Birmingham
# Successfully fetched data from page 5 for Birmingham
# Successfully fetched data from page 6 for Birmingham
# Successfully fetched data from page 7 for Birmingham
# Successfully fetched data from page 8 for Birmingham
# Successfully fetched data from page 9 for Birmingham
# Successfully fetched data from page 10 for Birmingham
# No more data found on page 11. Ending pagination.
# Total restaurants fetched for Birmingham: 139

# %%
import requests
import json
import os
import time

# Path to the input JSON file that contains restaurant data
input_file = r"/content/manchester.json"
output_file = r"/content/manchester_resturants_details.json"

# Check if the JSON file with restaurant data exists
if not os.path.exists(input_file):
    print("Error: Restaurant data file not found. Please ensure the file exists and try again.")
    exit()

# Load the restaurant data from the JSON file
with open(input_file, 'r') as file:
    all_restaurants = json.load(file)

# Extract the slugs (restaurant names) from the restaurant data
restaurant_slugs = [restaurant['slug'] for restaurant in all_restaurants if 'slug' in restaurant]

# Base URL for fetching restaurant details
details_base_url = "https://api.neotaste.com/restaurants/"

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# List to store all fetched restaurant details
restaurant_details_list = []

# Loop through each slug and fetch its details
for index, slug in enumerate(restaurant_slugs, start=1):
    # Construct the URL for the current restaurant
    details_url = f"{details_base_url}{slug}/"

    # Send a GET request to the API
    response = requests.get(details_url, headers=headers)

    if response.status_code == 200:
        # Parse the JSON data from the response
        restaurant_details = response.json()

        # Add the restaurant details to the list
        restaurant_details_list.append(restaurant_details)
        print(f"Fetched details for restaurant {index}/{len(restaurant_slugs)}: {slug}")
    else:
        # Log the error if the request fails
        print(f"Error: Unable to fetch details for {slug} (Status code: {response.status_code})")

    # Optional: Add a delay to avoid rate-limiting
    time.sleep(1)

# Save the fetched restaurant details to the output JSON file
with open(output_file, 'w') as file:
    json.dump(restaurant_details_list, file, indent=4)

print(f"Details of all restaurants have been saved to {output_file}")
# Out:
# Fetched details for restaurant 1/184: no-gift-yet-manchester
# Fetched details for restaurant 2/184: tsujiri-chinatown
# Fetched details for restaurant 3/184: fluffy-fluffy-manchester
# Fetched details for restaurant 4/184: noodle-alley
# Fetched details for restaurant 5/184: hello-oriental
# Fetched details for restaurant 6/184: north-taproom-circle-square
# Fetched details for restaurant 7/184: fig-sparrow
# Fetched details for restaurant 8/184: can-petit
# Fetched details for restaurant 9/184: cocoa-cabana-ancoats
# Fetched details for restaurant 10/184: grill-house
# Fetched details for restaurant 11/184: coffee-rules-manchester
# Fetched details for restaurant 12/184: rustik-bites
# Fetched details for restaurant 13/184: bupang-yogurt
# Fetched details for restaurant 14/184: coffee-rules-salford
# Fetched details for restaurant 15/184: ashas
# Fetched details for restaurant 16/184: the-green-lab
# Fetched details for restaurant 17/184: suki-suki-street-food-bar
# Fetched details for restaurant 18/184: boogalu-cocktail-bar-taqueria
# Fetched details for restaurant 19/184: meridian-cafe-bar
# Fetched details for restaurant 20/184: kongs-nq
# Fetched details for restaurant 21/184: off-the-press
# Fetched details for restaurant 22/184: jane-eyre
# Fetched details for restaurant 23/184: blue-eyed-panda
# Fetched details for restaurant 24/184: 92-degrees-coffee-john-dalton-st
# Fetched details for restaurant 25/184: flok
# Fetched details for restaurant 26/184: bondi-bowls
# Fetched details for restaurant 27/184: alexs-bakery
# Fetched details for restaurant 28/184: base-kamp-cafe
# Fetched details for restaurant 29/184: under-the-grill
# Fetched details for restaurant 30/184: rola-wala
# Fetched details for restaurant 31/184: calcio
# Fetched details for restaurant 32/184: scoop
# Fetched details for restaurant 33/184: inner-west
# Fetched details for restaurant 34/184: the-brewentists
# Fetched details for restaurant 35/184: chef-platters
# Fetched details for restaurant 36/184: la-collina
# Fetched details for restaurant 37/184: atrium-coffee
# Fetched details for restaurant 38/184: sipp-coffee-ancoats
# Fetched details for restaurant 39/184: ditto-coffee
# Fetched details for restaurant 40/184: sipp-coffee-new-jackson
# Fetched details for restaurant 41/184: giovannis-cafe-7-new-york-st
# Fetched details for restaurant 42/184: the-fitzgerald
# Fetched details for restaurant 43/184: hula-tiki
# Fetched details for restaurant 44/184: coffii-22
# Fetched details for restaurant 45/184: bar-fringe
# Fetched details for restaurant 46/184: only-yu-oriental-cuisine
# Fetched details for restaurant 47/184: coffee-lab
# Fetched details for restaurant 48/184: michaels-coffee-house
# Fetched details for restaurant 49/184: bowlers
# Fetched details for restaurant 50/184: house-of-chai
# Fetched details for restaurant 51/184: uncle-t
# Fetched details for restaurant 52/184: greek-gyros-bar
# Fetched details for restaurant 53/184: java-bar-espresso
# Fetched details for restaurant 54/184: little-aladdin-vegan-cafe
# Fetched details for restaurant 55/184: otters-in-a-pot
# Fetched details for restaurant 56/184: chai-latte
# Fetched details for restaurant 57/184: connis-focacceria
# Fetched details for restaurant 58/184: waffle-island
# Fetched details for restaurant 59/184: saison
# Fetched details for restaurant 60/184: the-great-kathmandu-restaurant
# Fetched details for restaurant 61/184: bebes-shawarma
# Fetched details for restaurant 62/184: marsa-cafe
# Fetched details for restaurant 63/184: cuppellos-coffee-juice
# Fetched details for restaurant 64/184: bee-orchid
# Fetched details for restaurant 65/184: my-dear-bubble-tea
# Fetched details for restaurant 66/184: hudsons-desserts
# Fetched details for restaurant 67/184: 92-degrees-spinningfields
# Fetched details for restaurant 68/184: cafe-beermoth-craft-beer-bar
# Fetched details for restaurant 69/184: wanago-sushi-street-food-bar
# Fetched details for restaurant 70/184: zara-mediterranean
# Fetched details for restaurant 71/184: coffee-b
# Fetched details for restaurant 72/184: the-bakery-mcr
# Fetched details for restaurant 73/184: three-brothers-cafe
# Fetched details for restaurant 74/184: chunky-fried-chicken
# Fetched details for restaurant 75/184: 92-degrees-coffee-salford
# Fetched details for restaurant 76/184: behind-closed-doors
# Fetched details for restaurant 77/184: the-cake-gallery
# Fetched details for restaurant 78/184: nightcap
# Fetched details for restaurant 79/184: nostro-cafe
# Fetched details for restaurant 80/184: big-licks
# Fetched details for restaurant 81/184: fusion-plate-sale
# Fetched details for restaurant 82/184: cocoa-cabana-chocolatiers
# Fetched details for restaurant 83/184: home-bar-kitchen
# Fetched details for restaurant 84/184: batch-bottlestore
# Fetched details for restaurant 85/184: track-brewing-co
# Fetched details for restaurant 86/184: my-karak-chai-wilbraham-rd
# Fetched details for restaurant 87/184: fusion-plate-altrincham
# Fetched details for restaurant 88/184: memories-cafe-bar
# Fetched details for restaurant 89/184: olivitta-deli-bar
# Fetched details for restaurant 90/184: tegtat
# Fetched details for restaurant 91/184: the-tootal-buildings
# Fetched details for restaurant 92/184: dragon-oriental-restaurant
# Fetched details for restaurant 93/184: takoyaki-master-manchester
# Fetched details for restaurant 94/184: the-drop-bar-cafe
# Fetched details for restaurant 95/184: eat-2-treat
# Fetched details for restaurant 96/184: hive-skate-hub
# Fetched details for restaurant 97/184: il-circolo-at-home-bar-kitchen
# Fetched details for restaurant 98/184: sicilian-nq-restaurant
# Fetched details for restaurant 99/184: little-fern-at-home-bar-kitchen
# Fetched details for restaurant 100/184: connis-pizzeria
# Fetched details for restaurant 101/184: home-comforts-at-home-bar-kitchen
# Fetched details for restaurant 102/184: three-brothers
# Fetched details for restaurant 103/184: syriana-urmston
# Fetched details for restaurant 104/184: i-call-myself-sanchez
# Fetched details for restaurant 105/184: meokja
# Fetched details for restaurant 106/184: great-guys
# Fetched details for restaurant 107/184: tsujiri-circle-square
# Fetched details for restaurant 108/184: lotus-food
# Fetched details for restaurant 109/184: spice-and-grind
# Fetched details for restaurant 110/184: monkey-trio
# Fetched details for restaurant 111/184: kaya-malaysian-restaurant
# Fetched details for restaurant 112/184: sadaf-restaurant
# Fetched details for restaurant 113/184: crunchy-bite
# Fetched details for restaurant 114/184: the-waterside-bar-and-restaurant
# Fetched details for restaurant 115/184: sansou
# Fetched details for restaurant 116/184: loaded
# Fetched details for restaurant 117/184: seaworld-restaurant
# Fetched details for restaurant 118/184: siphon-espresso
# Fetched details for restaurant 119/184: papa-dutch-the-little-dutch-cafe
# Fetched details for restaurant 120/184: bahar-cafe
# Fetched details for restaurant 121/184: hq
# Fetched details for restaurant 122/184: on-bar
# Fetched details for restaurant 123/184: the-church
# Fetched details for restaurant 124/184: the-beacon
# Fetched details for restaurant 125/184: bun
# Fetched details for restaurant 126/184: caseys-corner
# Fetched details for restaurant 127/184: tavern-on-the-green
# Fetched details for restaurant 128/184: beirut-restaurant
# Fetched details for restaurant 129/184: all-press-espresso
# Fetched details for restaurant 130/184: oats-honey
# Fetched details for restaurant 131/184: waku-waku
# Fetched details for restaurant 132/184: lahori-badsha
# Fetched details for restaurant 133/184: black-cat-club
# Fetched details for restaurant 134/184: gharaana
# Fetched details for restaurant 135/184: enoteca
# Fetched details for restaurant 136/184: munchyhub
# Fetched details for restaurant 137/184: ld24-coffee
# Fetched details for restaurant 138/184: multea-choice-bubble-tea
# Fetched details for restaurant 139/184: band-on-the-wall
# Fetched details for restaurant 140/184: noodle-house
# Fetched details for restaurant 141/184: exchange-food-drink-lounge
# Fetched details for restaurant 142/184: spice-grind-eden
# Fetched details for restaurant 143/184: little-piece-of-bahia
# Fetched details for restaurant 144/184: zoroona
# Fetched details for restaurant 145/184: the-whiskey-jar
# Fetched details for restaurant 146/184: ayas-restaurant
# Fetched details for restaurant 147/184: yetenbi-kitfo
# Fetched details for restaurant 148/184: salis-souvlaki
# Fetched details for restaurant 149/184: gk-gallery-tea-room
# Fetched details for restaurant 150/184: renis-african-restaurant
# Fetched details for restaurant 151/184: lahori-ice-bar
# Fetched details for restaurant 152/184: uva-loca-x-stacks
# Fetched details for restaurant 153/184: home-community-cafe
# Fetched details for restaurant 154/184: chatime
# Fetched details for restaurant 155/184: yano-cha
# Fetched details for restaurant 156/184: casablanca-restaurant
# Fetched details for restaurant 157/184: the-plant-boost
# Fetched details for restaurant 158/184: pizza-anna
# Fetched details for restaurant 159/184: eccles-comunity-cafe
# Fetched details for restaurant 160/184: gin-can
# Fetched details for restaurant 161/184: red-sea-manchester
# Fetched details for restaurant 162/184: serendipitea-coffee
# Fetched details for restaurant 163/184: strange-brew
# Fetched details for restaurant 164/184: california-coffee-wine
# Fetched details for restaurant 165/184: grand-daddys-diner
# Fetched details for restaurant 166/184: quarter-house-beer-bbq
# Fetched details for restaurant 167/184: worsley-coffee-co
# Fetched details for restaurant 168/184: block-steak-shop
# Fetched details for restaurant 169/184: sherbet
# Fetched details for restaurant 170/184: parmogeddon
# Fetched details for restaurant 171/184: dou-bagels-cafe
# Fetched details for restaurant 172/184: ancoats-wine-and-coffee-club
# Fetched details for restaurant 173/184: bocaditos-tapas-bar-deli
# Fetched details for restaurant 174/184: bruco-italian-bar-kitchen
# Fetched details for restaurant 175/184: ik-burgers
# Fetched details for restaurant 176/184: hinterland-alcohol-free-bar-and-cafe
# Fetched details for restaurant 177/184: ariyadh-arabic-restaurant
# Fetched details for restaurant 178/184: hale-turkish-restaurant
# Fetched details for restaurant 179/184: bruncho
# Fetched details for restaurant 180/184: house-of-boba
# Fetched details for restaurant 181/184: elise-gaston
# Fetched details for restaurant 182/184: po-boys
# Fetched details for restaurant 183/184: on-the-hush
# Fetched details for restaurant 184/184: another-heart-to-feed
# Details of all restaurants have been saved to /content/manchester_resturants_details.json

# %%
import json

def process_json_file(input_file_path, output_file_path):
    # Open the input file and load the JSON data
    with open(input_file_path, 'r') as input_file:
        data = json.load(input_file)

    output_data = {}

    # Check if the data is a list or a dictionary
    if isinstance(data, list):
        # If it's a list, loop through items and check if 'data' and 'uuid' exist
        for item in data:
            if 'data' in item and 'uuid' in item['data']:
                # Use the uuid as the key and the contents of 'data' as the value
                output_data[item['data']['uuid']] = item['data']
            else:
                # Handle cases where 'uuid' is missing
                print(f"Item missing 'uuid': {item}")
    elif isinstance(data, dict):
        # If it's a dictionary, just create uuid as the key if it exists in 'data'
        if 'data' in data and 'uuid' in data['data']:
            output_data[data['data']['uuid']] = data['data']
        else:
            print("The dictionary is missing a 'uuid' key in 'data'.")
    else:
        raise TypeError("Expected input to be a list or dictionary")

    # Save the output JSON to a file
    with open(output_file_path, 'w') as output_file:
        json.dump(output_data, output_file, indent=4)

# Example usage
input_file_path =r'/content/birmingham_resturants_details.json'
output_file_path = r'/content/birmingham_resturants_details_uuid.json'

process_json_file(input_file_path, output_file_path)

# %%
import json
import os

# Path to the input JSON file
input_file = r"/content/resturants_details_uuid.json"
output_file = r"/content/resturants_details_uuid_c.json"

# Check if the JSON file exists
if not os.path.exists(input_file):
    print("Error: Input JSON file not found. Please ensure the file exists and try again.")
    exit()

# Load the JSON data from the file
with open(input_file, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Save the JSON with visible Unicode characters
with open(output_file, 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

print(f"JSON data with visible Unicode characters saved to {output_file}")
# Out:
# JSON data with visible Unicode characters saved to /content/resturants_details_uuid_c.json
